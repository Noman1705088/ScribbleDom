# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_man = pd.read_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/manual_annotations.csv', index_col=0)

# %%
df_man = df_man.fillna(-1)

# %%
df_man
# Out:
#        label
# 7x15     0.0
# 7x16     3.0
# 7x17     3.0
# 7x18     3.0
# 8x13     3.0
# ...      ...
# 27x18    2.0
# 27x19    2.0
# 27x20    3.0
# 27x21    1.0
# 27x22    1.0
#
# [293 rows x 1 columns]

# %%
x_pixels = []
y_pixels = []

for spot in df_man.index:
    y_pixels.append(int(spot.split('x')[1]))
    x_pixels.append(int(spot.split('x')[0]))

# %%
color_map = {
    -1: 'black',
    0: 'red',
    1: 'green',
    2: 'blue',
    3: 'purple',
}

# %%
plt.scatter(y_pixels, x_pixels, c=list(map(lambda x: color_map[x], df_man['label'])))

# %%
df_man
# Out:
#        label
# 7x15     0.0
# 7x16     3.0
# 7x17     3.0
# 7x18     3.0
# 8x13     3.0
# ...      ...
# 27x18    2.0
# 27x19    2.0
# 27x20    3.0
# 27x21    1.0
# 27x22    1.0
#
# [293 rows x 1 columns]

# %%
df_annoatated = df_man.loc[(df_man['label'] != -1) & (df_man['label'] != 3)]

# %%
df_annoatated.rename(columns={'label': 'label_ann'}, inplace=True)
# Out:
# /tmp/ipykernel_28447/1899808336.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_annoatated.rename(columns={'label': 'label_ann'}, inplace=True)

# %%
df_annoatated.to_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/manual_annotations_wo_unannotated_reg.csv')

# %%
df_ann = pd.read_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/manual_annotations_wo_unannotated_reg.csv', index_col=0)
df_man_ = pd.read_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/manual_annotations.csv', index_col=0)

# %%
df_ann.index
# Out:
# Index(['7x15', '8x15', '9x17', '10x16', '11x13', '11x14', '11x15', '12x12',
#        '12x13', '12x14',
#        ...
#        '26x19', '26x21', '26x22', '26x23', '27x15', '27x17', '27x18', '27x19',
#        '27x21', '27x22'],
#       dtype='object', length=165)

# %%
df_man_
# Out:
#        label
# 7x15     0.0
# 7x16     3.0
# 7x17     3.0
# 7x18     3.0
# 8x13     3.0
# ...      ...
# 27x18    2.0
# 27x19    2.0
# 27x20    3.0
# 27x21    1.0
# 27x22    1.0
#
# [293 rows x 1 columns]

# %%
df_man_.loc[df_ann.index]
# Out:
#        label
# 7x15     0.0
# 8x15     0.0
# 9x17     1.0
# 10x16    1.0
# 11x13    1.0
# ...      ...
# 27x17    2.0
# 27x18    2.0
# 27x19    2.0
# 27x21    1.0
# 27x22    1.0
#
# [165 rows x 1 columns]

# %%
df_ann.rename(columns={'label': 'label_ann'}, inplace = True)
# rankings_pd.rename(columns = {'test':'TEST'}, inplace = True)

# %%
df_ann.join(df_man_)
# Out:
#        label_ann  label
# 7x15         0.0    0.0
# 8x15         0.0    0.0
# 9x17         1.0    1.0
# 10x16        1.0    1.0
# 11x13        1.0    1.0
# ...          ...    ...
# 27x17        2.0    2.0
# 27x18        2.0    2.0
# 27x19        2.0    2.0
# 27x21        1.0    1.0
# 27x22        1.0    1.0
#
# [165 rows x 2 columns]

# %%
df_ann.index
# Out:
# Index(['7x15', '8x15', '9x17', '10x16', '11x13', '11x14', '11x15', '12x12',
#        '12x13', '12x14',
#        ...
#        '26x19', '26x21', '26x22', '26x23', '27x15', '27x17', '27x18', '27x19',
#        '27x21', '27x22'],
#       dtype='object', length=165)

# %%
df_man_['7x15']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '7x15'
#
# ...

# %%
df_man[df_ann.index[122]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/envs/scribble_seg/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '23x16'
#
# ...
