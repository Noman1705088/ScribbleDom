# %%
import numpy as np
import pandas as pd

# %%
df_bayes_count = pd.read_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/count_matrix_from_BayesSpace_getrds.csv', index_col=0)

# %%
df_bayes_count.T
# Out:
#        PSME2  CUEDC1  RPLP1  TM9SF3  DEF8  RPL37A  NELL1  MFGE8  AIP  TSC22D3  \
# 7x15       2       0     21       0     0      28      2      2    1        0
# 7x16       0       0     13       0     0      13      0      3    0        0
# 7x17       0       0     13       0     0      15      0      2    0        0
# 7x18       0       1     18       0     1      17      2      3    1        0
# 8x13       0       0     10       0     0       3      0      2    0        0
# ...      ...     ...    ...     ...   ...     ...    ...    ...  ...      ...
# 27x18      0       0     17       0     0       9      0      0    0        0
# 27x19      0       2     16       0     0       8      0      2    1        0
# 27x20      0       0     37       0     0      16      1      2    0        0
# 27x21      1       0     24       0     0      18      1      0    0        0
# 27x22      3       0     20       2     1      13      0      2    1        0
#
# ...

# %%
df_orig_count = pd.read_csv('/home/nuwaisir/Corridor/Thesis_ug/ScribbleSeg_Revision_working/Data/others/Melanoma/ST_mel1_rep2_counts.tsv', sep='\t', index_col=0)

# %%
np.unique(df_orig_count.T.values == df_bayes_count.T.values)
# Out:
# array([ True])
